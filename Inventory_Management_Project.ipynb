# %%
import json
import time


def Add_New_Item():

    items={1:{"Name":"Chocolates", "MRP":5, "Quantity":300, "Discount":"10%", "Item_Type":"Chocolates"},
    2:{"Name":"Biscuit", "MRP":10, "Quantity":290, "Discount":"10%", "Item_Type":"Biscuit"},
    3:{"Name":"Water_Bottle", "MRP":15, "Quantity":280, "Discount":"10%", "Item_Type":"Water"},
    4:{"Name":"Cold_Drink", "MRP":20, "Quantity":270, "Discount":"10%", "Item_Type":"Drink"},
    5:{"Name":"Ice_Cream", "MRP":25, "Quantity":260, "Discount":"10%", "Item_Type":"Veg"},
    6:{"Name":"Cheese_Samosa", "MRP":30, "Quantity":250, "Discount":"10%", "Item_Type":"Veg"},
    7:{"Name":"Cold_Coffee", "MRP":35, "Quantity":240, "Discount":"10%", "Item_Type":"Cold_Drink"},
    8:{"Name":"Sample_Soup", "MRP":40, "Quantity":230, "Discount":"10%", "Item_Type":"Veg_Soup"},
    9:{"Name":"Fruit_Juice", "MRP":45, "Quantity":220, "Discount":"10%", "Item_Type":"Juice"},
    10:{"Name":"Pasta", "MRP":50, "Quantity":210, "Discount":"10%", "Item_Type":"Veg"},
    11:{"Name":"Soya_Chili", "MRP":55, "Quantity":200, "Discount":"10%", "Item_Type":"Veg"},
    12:{"Name":"Veg_Manchurian", "MRP":60, "Quantity":190, "Discount":"10%", "Item_Type":"Veg"},
    13:{"Name":"Cake", "MRP":65, "Quantity":180, "Discount":"10%", "Item_Type":"Veg_Cake"},
    14:{"Name":"Maggi", "MRP":70, "Quantity":170, "Discount":"10%", "Item_Type":"Veg"},
    15:{"Name":"Munchaw_Soup", "MRP":75, "Quantity":160, "Discount":"10%", "Item_Type":"Veg_Soup"},
    16:{"Name":"Paneer", "MRP":80, "Quantity":150, "Discount":"10%", "Item_Type":"Veg"},
    17:{"Name":"Mango_Mastani", "MRP":85, "Quantity":140, "Discount":"10%", "Item_Type":"Drink"},
    18:{"Name":"Muttor_Paneer", "MRP":90, "Quantity":130, "Discount":"10%", "Item_Type":"Veg"},
    19:{"Name":"Pav_Bhaji_Thali", "MRP":95, "Quantity":120, "Discount":"10%", "Item_Type":"Veg"},
    20:{"Name":"Jumbo_Cold_Drink_Pack", "MRP":100, "Quantity":110, "Discount":"10%", "Item_Type":"Cold_Drinks"},
    21:{"Name":"Rice_Thali", "MRP":105, "Quantity":100, "Discount":"10%", "Item_Type":"Veg"},
    22:{"Name":"Pastries", "MRP":110, "Quantity":90, "Discount":"10%", "Item_Type":"Veg"},
    23:{"Name":"Egg_Aumlet", "MRP":115, "Quantity":80, "Discount":"10%", "Item_Type":"Non_Veg"},
    24:{"Name":"Chinese", "MRP":120, "Quantity":70, "Discount":"10%", "Item_Type":"Veg_Chinese"},
    25:{"Name":"Ice_Cream_Family_Pack", "MRP":125, "Quantity":60, "Discount":"10%", "Item_Type":"Family_Pack"},
    26:{"Name":"Veg_Thali", "MRP":130, "Quantity":50, "Discount":"10%", "Item_Type":"Veg"},
    27:{"Name":"Chicken", "MRP":135, "Quantity":40, "Discount":"10%", "Item_Type":"Non_Veg"},
    29:{"Name":"Burger", "MRP":140, "Quantity":30, "Discount":"10%", "Item_Type":"Veg"},
    28:{"Name":"Pizza", "MRP":145, "Quantity":20, "Discount":"10%", "Item_Type":"Veg"},
    30:{"Name":"Ice_Cake", "MRP":150, "Quantity":10, "Discount":"10%", "Item_Type":"Cake"}
    }




    items=json.dumps(items)

    fd=open("items.json",'w')
    fd.write(items)
    fd.close()

    fd=open("items.json",'r')
    item=fd.read()
    fd.close()

    items=json.loads(item)
    

    #Item_ID =items
    #Item_ID =int(input("Enter New item ID :"))
    Item_Name=str(input("Enter new item name :"))
    Item_MRP=int(input("Enter new item MRP :"))
    Item_Quantity=int(input("Enter new item Quantity :"))
    Item_Discount=str(input("Enter Discount on new item :"))
    Type_Of_Item=str(input("Enter type of item :"))
    #Item_Sold_Quantity=print(int(input("Enter sold Quantity of new item :")))
    
    items[len(items)+1] = {'Name':Item_Name, 'MRP':Item_MRP, 'Quantity':Item_Quantity, 'Discount':Item_Discount, 'Item_Type':Type_Of_Item}
    #print(items[Item_ID])
    print(items)
    new_item=json.dumps(items)
    fd=open("items.json",'w')
    file=fd.write(new_item)
    fd.close()

    json.loads(new_item)
    


    #New_Added=items[str(len(items) + 1)]={Item_ID : {"Item_Name":Item_Name, "MRP":Item_MRP, "Quantity":Item_Quantity, "Discount":Item_Discount, "sold_quantity":0}}
    #print(New_Added)
    #print(items[str(len(items) + 1)])

def Sale_An_Item():
    file = open("items.json","r")


    items = file.read()
    items = json.loads(items)
    file.close()

    #while((items[str(prod_id_number)]["Quantity"])> 0):

    prod_id_number=int(input("enter item number : "))
    quant=int(input("enter quantity of item : "))



    print("***************************************WEL-COME******************************************")
        #order=int(input("enter how many items do you want to enter :"))

    for i in items:
        if(i<= str(prod_id_number)):
       
            print("BILLING_RECEIPT-------Order placed on :",time.ctime())
            print("name of item is :",items[str(prod_id_number)]["Name"])
            print("id of item :",prod_id_number)
            print("number of items ordered :",quant)
        
            print("MRP of item is :",items[str(prod_id_number)]["MRP"],"Rs.")


       
            print("Type of item :",items[str(prod_id_number)]["Item_Type"])
        
            print("Discount per item is :",items[str(prod_id_number)]["Discount"])
            discount=(((items[str(prod_id_number)]["MRP"])*10)/100)*quant
            total_price=(((items[str(prod_id_number)]["MRP"])*quant)-(discount))
            print("total price of order is :",(total_price),"Rs.")
    
            break;

    print("************************************VISIT-AGAIN******************************************")


    items[str(prod_id_number)]["Quantity"] = (items[str(prod_id_number)]["Quantity"])-quant

    js = json.dumps(items)

    fd=open("items.json",'w')
    fd.write(js)
    fd.close()

    fd=open("items.json",'r')
    txt=fd.read()
    fd.close()

    items=json.loads(txt)

    #print(txt)
    #print(type(items)) 
    #print(items)

    #print((items[str(number)]["Quantity"])-quant)
    #items[str(number)]["Quantity"]-=quant
    #print(items[str(number)]["Quantity"])

    sales={3:{"PRODUCT_ID":prod_id_number,"PURCHASED_QUANTITY":quant,"BILLING_AMOUNT":total_price}}

    sales[len(sales )+1]:{"Item_Name":items[str(prod_id_number)]["Name"],"PRODUCT_ID":prod_id_number,"PURCHASED_QUANTITY":quant,"BILLING_AMOUNT":total_price}

    print(sales)

    sales=json.dumps(sales)

    fd=open("sales.json",'w')
    fd.write(sales)
    fd.close()

    fd=open("sales.json",'r')
    sold=fd.read()
    fd.close()

    sales=json.loads(sold)




print("1 = Add New Item to Inventory")
print("2 = Purchase Item")

choice=int(input("Enter your choice here :"))

if(choice==1):
    Add_New_Item()

if(choice==2):
    Sale_An_Item()
# Out:
# 1 = Add New Item to Inventory
# 2 = Purchase Item
# Enter your choice here :2
# enter item number : 2
# enter quantity of item : 2
# ***************************************WEL-COME******************************************
# BILLING_RECEIPT-------Order placed on : Sun Sep  5 16:52:14 2021
# name of item is : Biscuit
# id of item : 2
# number of items ordered : 2
# MRP of item is : 10 Rs.
# Type of item : Biscuit
# Discount per item is : 10%
# total price of order is : 18.0 Rs.
# ************************************VISIT-AGAIN******************************************
# {3: {'PRODUCT_ID': 2, 'PURCHASED_QUANTITY': 2, 'BILLING_AMOUNT': 18.0}}

# %%
2
